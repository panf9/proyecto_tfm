# %%
pip install gradio
# Out:
# Collecting gradio
#   Downloading gradio-5.24.0-py3-none-any.whl.metadata (16 kB)
# Collecting aiofiles<25.0,>=22.0 (from gradio)
#   Downloading aiofiles-24.1.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: anyio<5.0,>=3.0 in /home/frank/miniconda3/envs/env_code/lib/python3.12/site-packages (from gradio) (4.9.0)
# Collecting fastapi<1.0,>=0.115.2 (from gradio)
#   Downloading fastapi-0.115.12-py3-none-any.whl.metadata (27 kB)
# Collecting ffmpy (from gradio)
#   Downloading ffmpy-0.5.0-py3-none-any.whl.metadata (3.0 kB)
# Collecting gradio-client==1.8.0 (from gradio)
#   Downloading gradio_client-1.8.0-py3-none-any.whl.metadata (7.1 kB)
# Collecting groovy~=0.1 (from gradio)
#   Downloading groovy-0.1.2-py3-none-any.whl.metadata (6.1 kB)
# Requirement already satisfied: httpx>=0.24.1 in /home/frank/miniconda3/envs/env_code/lib/python3.12/site-packages (from gradio) (0.28.1)
# Requirement already satisfied: huggingface-hub>=0.28.1 in /home/frank/miniconda3/envs/env_code/lib/python3.12/site-packages (from gradio) (0.30.1)
# Requirement already satisfied: jinja2<4.0 in /home/frank/miniconda3/envs/env_code/lib/python3.12/site-packages (from gradio) (3.1.6)
# Requirement already satisfied: markupsafe<4.0,>=2.0 in /home/frank/miniconda3/envs/env_code/lib/python3.12/site-packages (from gradio) (3.0.2)
# Requirement already satisfied: numpy<3.0,>=1.0 in /home/frank/miniconda3/envs/env_code/lib/python3.12/site-packages (from gradio) (2.1.2)
# Collecting orjson~=3.0 (from gradio)
#   Downloading orjson-3.10.16-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (41 kB)
# Requirement already satisfied: packaging in /home/frank/miniconda3/envs/env_code/lib/python3.12/site-packages (from gradio) (24.2)
# Requirement already satisfied: pandas<3.0,>=1.0 in /home/frank/miniconda3/envs/env_code/lib/python3.12/site-packages (from gradio) (2.2.3)
# Requirement already satisfied: pillow<12.0,>=8.0 in /home/frank/miniconda3/envs/env_code/lib/python3.12/site-packages (from gradio) (11.0.0)
# Requirement already satisfied: pydantic<2.12,>=2.0 in /home/frank/miniconda3/envs/env_code/lib/python3.12/site-packages (from gradio) (2.11.2)
# Collecting pydub (from gradio)
#   Downloading pydub-0.25.1-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting python-multipart>=0.0.18 (from gradio)
#   Downloading python_multipart-0.0.20-py3-none-any.whl.metadata (1.8 kB)
# Requirement already satisfied: pyyaml<7.0,>=5.0 in /home/frank/miniconda3/envs/env_code/lib/python3.12/site-packages (from gradio) (6.0.2)
# Collecting ruff>=0.9.3 (from gradio)
#   Downloading ruff-0.11.4-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (25 kB)
# Collecting safehttpx<0.2.0,>=0.1.6 (from gradio)
#   Downloading safehttpx-0.1.6-py3-none-any.whl.metadata (4.2 kB)
# Collecting semantic-version~=2.0 (from gradio)
#   Downloading semantic_version-2.10.0-py2.py3-none-any.whl.metadata (9.7 kB)
# Collecting starlette<1.0,>=0.40.0 (from gradio)
#   Downloading starlette-0.46.1-py3-none-any.whl.metadata (6.2 kB)
# Collecting tomlkit<0.14.0,>=0.12.0 (from gradio)
#   Downloading tomlkit-0.13.2-py3-none-any.whl.metadata (2.7 kB)
# Collecting typer<1.0,>=0.12 (from gradio)
#   Downloading typer-0.15.2-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: typing-extensions~=4.0 in /home/frank/miniconda3/envs/env_code/lib/python3.12/site-packages (from gradio) (4.13.1)
# Collecting uvicorn>=0.14.0 (from gradio)
#   Downloading uvicorn-0.34.0-py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: fsspec in /home/frank/miniconda3/envs/env_code/lib/python3.12/site-packages (from gradio-client==1.8.0->gradio) (2024.12.0)
# Collecting websockets<16.0,>=10.0 (from gradio-client==1.8.0->gradio)
#   Downloading websockets-15.0.1-cp312-cp312-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.8 kB)
# Requirement already satisfied: idna>=2.8 in /home/frank/miniconda3/envs/env_code/lib/python3.12/site-packages (from anyio<5.0,>=3.0->gradio) (3.10)
# Requirement already satisfied: sniffio>=1.1 in /home/frank/miniconda3/envs/env_code/lib/python3.12/site-packages (from anyio<5.0,>=3.0->gradio) (1.3.1)
# Requirement already satisfied: certifi in /home/frank/miniconda3/envs/env_code/lib/python3.12/site-packages (from httpx>=0.24.1->gradio) (2025.1.31)
# Requirement already satisfied: httpcore==1.* in /home/frank/miniconda3/envs/env_code/lib/python3.12/site-packages (from httpx>=0.24.1->gradio) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /home/frank/miniconda3/envs/env_code/lib/python3.12/site-packages (from httpcore==1.*->httpx>=0.24.1->gradio) (0.14.0)
# Requirement already satisfied: filelock in /home/frank/miniconda3/envs/env_code/lib/python3.12/site-packages (from huggingface-hub>=0.28.1->gradio) (3.18.0)
# Requirement already satisfied: requests in /home/frank/miniconda3/envs/env_code/lib/python3.12/site-packages (from huggingface-hub>=0.28.1->gradio) (2.32.3)
# Requirement already satisfied: tqdm>=4.42.1 in /home/frank/miniconda3/envs/env_code/lib/python3.12/site-packages (from huggingface-hub>=0.28.1->gradio) (4.67.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/frank/miniconda3/envs/env_code/lib/python3.12/site-packages (from pandas<3.0,>=1.0->gradio) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/frank/miniconda3/envs/env_code/lib/python3.12/site-packages (from pandas<3.0,>=1.0->gradio) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/frank/miniconda3/envs/env_code/lib/python3.12/site-packages (from pandas<3.0,>=1.0->gradio) (2025.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/frank/miniconda3/envs/env_code/lib/python3.12/site-packages (from pydantic<2.12,>=2.0->gradio) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.1 in /home/frank/miniconda3/envs/env_code/lib/python3.12/site-packages (from pydantic<2.12,>=2.0->gradio) (2.33.1)
# Requirement already satisfied: typing-inspection>=0.4.0 in /home/frank/miniconda3/envs/env_code/lib/python3.12/site-packages (from pydantic<2.12,>=2.0->gradio) (0.4.0)
# Requirement already satisfied: click>=8.0.0 in /home/frank/miniconda3/envs/env_code/lib/python3.12/site-packages (from typer<1.0,>=0.12->gradio) (8.1.8)
# Collecting shellingham>=1.3.0 (from typer<1.0,>=0.12->gradio)
#   Downloading shellingham-1.5.4-py2.py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: rich>=10.11.0 in /home/frank/miniconda3/envs/env_code/lib/python3.12/site-packages (from typer<1.0,>=0.12->gradio) (14.0.0)
# Requirement already satisfied: six>=1.5 in /home/frank/miniconda3/envs/env_code/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas<3.0,>=1.0->gradio) (1.17.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/frank/miniconda3/envs/env_code/lib/python3.12/site-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/frank/miniconda3/envs/env_code/lib/python3.12/site-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio) (2.19.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/frank/miniconda3/envs/env_code/lib/python3.12/site-packages (from requests->huggingface-hub>=0.28.1->gradio) (3.4.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/frank/miniconda3/envs/env_code/lib/python3.12/site-packages (from requests->huggingface-hub>=0.28.1->gradio) (2.3.0)
# Requirement already satisfied: mdurl~=0.1 in /home/frank/miniconda3/envs/env_code/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0,>=0.12->gradio) (0.1.2)
# Downloading gradio-5.24.0-py3-none-any.whl (46.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.9/46.9 MB 19.5 MB/s eta 0:00:0031m19.8 MB/s eta 0:00:01
# Downloading gradio_client-1.8.0-py3-none-any.whl (322 kB)
# Downloading aiofiles-24.1.0-py3-none-any.whl (15 kB)
# Downloading fastapi-0.115.12-py3-none-any.whl (95 kB)
# Downloading groovy-0.1.2-py3-none-any.whl (14 kB)
# Downloading orjson-3.10.16-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (133 kB)
# Downloading python_multipart-0.0.20-py3-none-any.whl (24 kB)
# Downloading ruff-0.11.4-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.3/11.3 MB 20.9 MB/s eta 0:00:00MB/s eta 0:00:01:01
# Downloading safehttpx-0.1.6-py3-none-any.whl (8.7 kB)
# Downloading semantic_version-2.10.0-py2.py3-none-any.whl (15 kB)
# Downloading starlette-0.46.1-py3-none-any.whl (71 kB)
# Downloading tomlkit-0.13.2-py3-none-any.whl (37 kB)
# Downloading typer-0.15.2-py3-none-any.whl (45 kB)
# Downloading uvicorn-0.34.0-py3-none-any.whl (62 kB)
# Downloading ffmpy-0.5.0-py3-none-any.whl (6.0 kB)
# Downloading pydub-0.25.1-py2.py3-none-any.whl (32 kB)
# Downloading shellingham-1.5.4-py2.py3-none-any.whl (9.8 kB)
# Downloading websockets-15.0.1-cp312-cp312-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (182 kB)
# Installing collected packages: pydub, websockets, uvicorn, tomlkit, shellingham, semantic-version, ruff, python-multipart, orjson, groovy, ffmpy, aiofiles, starlette, typer, safehttpx, gradio-client, fastapi, gradio
# Successfully installed aiofiles-24.1.0 fastapi-0.115.12 ffmpy-0.5.0 gradio-5.24.0 gradio-client-1.8.0 groovy-0.1.2 orjson-3.10.16 pydub-0.25.1 python-multipart-0.0.20 ruff-0.11.4 safehttpx-0.1.6 semantic-version-2.10.0 shellingham-1.5.4 starlette-0.46.1 tomlkit-0.13.2 typer-0.15.2 uvicorn-0.34.0 websockets-15.0.1
# Note: you may need to restart the kernel to use updated packages.

# %%
import gradio as gr
import torch
from transformers import AutoTokenizer, AutoModelForCausalLM
from safetensors.torch import load_model

# Configuración
MODEL_PATH = "./modelo"  # Ruta donde están tus archivos
DEVICE = "cuda" if torch.cuda.is_available() else "cpu"

# Cargar tokenizer y config
tokenizer = AutoTokenizer.from_pretrained("gpt2")
tokenizer.pad_token = tokenizer.eos_token  # Necesario para GPT-2

# Cargar modelo desde safetensors
model = AutoModelForCausalLM.from_pretrained(
    MODEL_PATH,
    local_files_only=True,
    torch_dtype=torch.float16 if DEVICE == "cuda" else torch.float32
).to(DEVICE)
model.eval()

def comentar_codigo(snippet):
    # Plantilla de prompt (ajusta según tu entrenamiento)
    prompt = f"Comenta este código Python:\n```python\n{snippet}\n```\nCódigo comentado:\n```python\n"
    
    inputs = tokenizer(
        prompt,
        return_tensors="pt",
        truncation=True,
        max_length=512
    ).to(DEVICE)
    
    with torch.no_grad():
        outputs = model.generate(
            **inputs,
            max_new_tokens=300,
            temperature=0.7,
            do_sample=True,
            pad_token_id=tokenizer.eos_token_id
        )
    
    # Decodificar y limpiar la salida
    full_output = tokenizer.decode(outputs[0], skip_special_tokens=True)
    codigo_comentado = full_output.split("Código comentado:")[-1].strip()
    
    # Eliminar el cierre del code block si existe
    return codigo_comentado.replace("```", "").strip()

# Interfaz mejorada
css = """
.code-output {
    font-family: monospace !important;
    white-space: pre;
}
"""
with gr.Blocks(css=css, title="Comentador GPT-2") as demo:
    gr.Markdown("## 💻 Comentador Automático de Código (GPT-2)")
    
    with gr.Row():
        input_code = gr.Code(
            label="Tu código",
            language="python",
            lines=15,
            elem_classes="code-output"
        )
        output_code = gr.Code(
            label="Código Comentado",
            language="python",
            lines=15,
            elem_classes="code-output"
        )
    
    btn = gr.Button("Generar Comentarios", variant="primary")
    
    # Ejemplos prácticos
    examples = [
        ["def factorial(n):\n    if n == 0:\n        return 1\n    return n * factorial(n-1)"],
        ["class Calculadora:\n    def __init__(self):\n        self.resultado = 0\n\n    def suma(self, a, b):\n        return a + b"],
        ["for i in range(10):\n    print(f'Valor: {i}')"]
    ]
    
    gr.Examples(examples=examples, inputs=input_code, label="Ejemplos")
    
    btn.click(
        fn=comentar_codigo,
        inputs=input_code,
        outputs=output_code
    )

demo.launch(
    server_name="0.0.0.0",
    share=False  # True para enlace público temporal
)
# Out:
# * Running on local URL:  http://0.0.0.0:7860
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://localhost:7860/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %% [markdown]
# # Métricas

# %%
import evaluate
import pandas as pd
import nltk
nltk.download("punkt")  # Requerido para METEOR
# Out:
# [nltk_data] Downloading package punkt to /home/frank/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
import evaluate
import nltk
import pandas as pd
from datasets import load_dataset
nltk.download("punkt")  # Necesario para METEOR

# ✅ Paso 1: Cargar el dataset
data_files = {
    'train': 'dataset_train.jsonl',
    'validation': 'dataset_valid.jsonl',
    'test': 'dataset_test.jsonl'
}

raw_datasets = load_dataset('json', data_files=data_files)
test_dataset = raw_datasets["test"]
# Out:
# [nltk_data] Downloading package punkt to /home/frank/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
print(test_dataset)
# Out:
# Dataset({
#     features: ['repo', 'path', 'func_name', 'original_string', 'language', 'code', 'code_tokens', 'docstring', 'docstring_tokens', 'sha', 'url', 'partition', 'code_clean'],
#     num_rows: 19916
# })

# %%
# ✅ Paso 2: Función para generar comentarios con tu modelo
def comentar_codigo(snippet):
    prompt = f"Comenta este código Python:\n```python\n{snippet}\n```\nCódigo comentado:\n```python\n"
    inputs = tokenizer(
        prompt,
        return_tensors="pt",
        truncation=True,
        max_length=512
    ).to(DEVICE)

    with torch.no_grad():
        outputs = model.generate(
            **inputs,
            max_new_tokens=512,
            temperature=0.7,
            do_sample=True,
            pad_token_id=tokenizer.eos_token_id
        )

    full_output = tokenizer.decode(outputs[0], skip_special_tokens=True)
    codigo_comentado = full_output.split("Código comentado:")[-1].strip()
    return codigo_comentado.replace("```", "").strip()

# %%
# ✅ Paso 3: Generar predicciones
preds = []
refs = []

for example in test_dataset:
    entrada = example['code_clean']
    salida_esperada = example["code"]
    comentario_generado = comentar_codigo(entrada)
    
    preds.append(comentario_generado)
    refs.append(salida_esperada)

# ✅ Paso 4: Cargar métricas
bleu = evaluate.load("bleu")
rouge = evaluate.load("rouge")
meteor = evaluate.load("meteor")

# ✅ Paso 5: Evaluar
bleu_score = bleu.compute(predictions=preds, references=refs)
rouge_score = rouge.compute(predictions=preds, references=refs)
meteor_score = meteor.compute(predictions=preds, references=refs)

# ✅ Paso 6: Mostrar resultados
print("\n BLEU:", bleu_score)
print("\n ROUGE:", rouge_score)
print("\n METEOR:", meteor_score)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 8
#       6 entrada = example['code_clean']
#       7 salida_esperada = example["code"]
# ----> 8 comentario_generado = comentar_codigo(entrada)
#      10 preds.append(comentario_generado)
#      11 refs.append(salida_esperada)
#
# Cell In[5], line 12, in comentar_codigo(snippet)
#       4 inputs = tokenizer(
#       5     prompt,
#       6     return_tensors="pt",
#       7     truncation=True,
#       8     max_length=512
#       9 ).to(DEVICE)
#      11 with torch.no_grad():
# ---> 12     outputs = model.generate(
#      13         **inputs,
#      14         max_new_tokens=512,
#      15         temperature=0.7,
#      16         do_sample=True,
#      17         pad_token_id=tokenizer.eos_token_id
#      18     )
#      20 full_output = tokenizer.decode(outputs[0], skip_special_tokens=True)
#      21 codigo_comentado = full_output.split("Código comentado:")[-1].strip()
#
# File ~/miniconda3/envs/blackwell/lib/python3.12/site-packages/torch/utils/_contextlib.py:116, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     113 @functools.wraps(func)
#     114 def decorate_context(*args, **kwargs):
#     115     with ctx_factory():
# --> 116         return func(*args, **kwargs)
#
# File ~/miniconda3/envs/blackwell/lib/python3.12/site-packages/transformers/generation/utils.py:2597, in GenerationMixin.generate(self, inputs, generation_config, logits_processor, stopping_criteria, prefix_allowed_tokens_fn, synced_gpus, assistant_model, streamer, negative_prompt_ids, negative_prompt_attention_mask, use_model_defaults, custom_generate, **kwargs)
#    2589     input_ids, model_kwargs = self._expand_inputs_for_generation(
#    2590         input_ids=input_ids,
#    2591         expand_size=generation_config.num_return_sequences,
#    2592         is_encoder_decoder=self.config.is_encoder_decoder,
#    2593         **model_kwargs,
#    2594     )
#    2596     # 12. run sample (it degenerates to greedy search when `generation_config.do_sample=False`)
# -> 2597     result = self._sample(
#    2598         input_ids,
#    2599         logits_processor=prepared_logits_processor,
#    2600         stopping_criteria=prepared_stopping_criteria,
#    2601         generation_config=generation_config,
#    2602         synced_gpus=synced_gpus,
#    2603         streamer=streamer,
#    2604         **model_kwargs,
#    2605     )
#    2607 elif generation_mode in (GenerationMode.BEAM_SAMPLE, GenerationMode.BEAM_SEARCH):
#    2608     # 11. interleave input_ids with `num_beams` additional sequences per batch
#    2609     input_ids, model_kwargs = self._expand_inputs_for_generation(
#    2610         input_ids=input_ids,
#    2611         expand_size=generation_config.num_beams,
#    2612         is_encoder_decoder=self.config.is_encoder_decoder,
#    2613         **model_kwargs,
#    2614     )
#
# File ~/miniconda3/envs/blackwell/lib/python3.12/site-packages/transformers/generation/utils.py:3560, in GenerationMixin._sample(self, input_ids, logits_processor, stopping_criteria, generation_config, synced_gpus, streamer, **model_kwargs)
#    3558     is_prefill = False
#    3559 else:
# -> 3560     outputs = model_forward(**model_inputs, return_dict=True)
#    3562 # synced_gpus: don't waste resources running the code we don't need; kwargs must be updated before skipping
#    3563 model_kwargs = self._update_model_kwargs_for_generation(
#    3564     outputs,
#    3565     model_kwargs,
#    3566     is_encoder_decoder=self.config.is_encoder_decoder,
#    3567 )
#
# File ~/miniconda3/envs/blackwell/lib/python3.12/site-packages/torch/nn/modules/module.py:1767, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1765     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1766 else:
# -> 1767     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/envs/blackwell/lib/python3.12/site-packages/torch/nn/modules/module.py:1778, in Module._call_impl(self, *args, **kwargs)
#    1773 # If we don't have any hooks, we want to skip the rest of the logic in
#    1774 # this function, and just call forward.
#    1775 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1776         or _global_backward_pre_hooks or _global_backward_hooks
#    1777         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1778     return forward_call(*args, **kwargs)
#    1780 result = None
#    1781 called_always_called_hooks = set()
#
# File ~/miniconda3/envs/blackwell/lib/python3.12/site-packages/transformers/models/gpt2/modeling_gpt2.py:1210, in GPT2LMHeadModel.forward(self, input_ids, past_key_values, cache_position, attention_mask, token_type_ids, position_ids, head_mask, inputs_embeds, encoder_hidden_states, encoder_attention_mask, labels, use_cache, output_attentions, output_hidden_states, return_dict, **kwargs)
#    1190 r"""
#    1191 input_ids (`torch.LongTensor` of shape `(batch_size, input_ids_length)`):
#    1192     `input_ids_length` = `sequence_length` if `past_key_values` is `None` else
#    (...)   1206     are ignored (masked), the loss is only computed for labels in `[0, ..., config.vocab_size]`
#    1207 """
#    1208 return_dict = return_dict if return_dict is not None else self.config.use_return_dict
# -> 1210 transformer_outputs = self.transformer(
#    1211     input_ids,
#    1212     past_key_values=past_key_values,
#    1213     attention_mask=attention_mask,
#    1214     cache_position=cache_position,
#    1215     token_type_ids=token_type_ids,
#    1216     position_ids=position_ids,
#    1217     head_mask=head_mask,
#    1218     inputs_embeds=inputs_embeds,
#    1219     encoder_hidden_states=encoder_hidden_states,
#    1220     encoder_attention_mask=encoder_attention_mask,
#    1221     use_cache=use_cache,
#    1222     output_attentions=output_attentions,
#    1223     output_hidden_states=output_hidden_states,
#    1224     return_dict=return_dict,
#    1225 )
#    1226 hidden_states = transformer_outputs[0]
#    1228 # Set device for model parallelism
#
# File ~/miniconda3/envs/blackwell/lib/python3.12/site-packages/torch/nn/modules/module.py:1767, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1765     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1766 else:
# -> 1767     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/envs/blackwell/lib/python3.12/site-packages/torch/nn/modules/module.py:1778, in Module._call_impl(self, *args, **kwargs)
#    1773 # If we don't have any hooks, we want to skip the rest of the logic in
#    1774 # this function, and just call forward.
#    1775 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1776         or _global_backward_pre_hooks or _global_backward_hooks
#    1777         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1778     return forward_call(*args, **kwargs)
#    1780 result = None
#    1781 called_always_called_hooks = set()
#
# File ~/miniconda3/envs/blackwell/lib/python3.12/site-packages/transformers/models/gpt2/modeling_gpt2.py:965, in GPT2Model.forward(self, input_ids, past_key_values, cache_position, attention_mask, token_type_ids, position_ids, head_mask, inputs_embeds, encoder_hidden_states, encoder_attention_mask, use_cache, output_attentions, output_hidden_states, return_dict, **kwargs)
#     962             if i == v[-1] and "cuda:" + str(k) != self.last_device:
#     963                 hidden_states = hidden_states.to("cuda:" + str(k + 1))
# --> 965 hidden_states = self.ln_f(hidden_states)
#     967 hidden_states = hidden_states.view(output_shape)
#     968 # Add last hidden state
#
# File ~/miniconda3/envs/blackwell/lib/python3.12/site-packages/torch/nn/modules/module.py:1767, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1765     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1766 else:
# -> 1767     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/envs/blackwell/lib/python3.12/site-packages/torch/nn/modules/module.py:1778, in Module._call_impl(self, *args, **kwargs)
#    1773 # If we don't have any hooks, we want to skip the rest of the logic in
#    1774 # this function, and just call forward.
#    1775 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1776         or _global_backward_pre_hooks or _global_backward_hooks
#    1777         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1778     return forward_call(*args, **kwargs)
#    1780 result = None
#    1781 called_always_called_hooks = set()
#
# File ~/miniconda3/envs/blackwell/lib/python3.12/site-packages/torch/nn/modules/normalization.py:217, in LayerNorm.forward(self, input)
#     216 def forward(self, input: Tensor) -> Tensor:
# --> 217     return F.layer_norm(
#     218         input, self.normalized_shape, self.weight, self.bias, self.eps
#     219     )
#
# File ~/miniconda3/envs/blackwell/lib/python3.12/site-packages/torch/nn/functional.py:2919, in layer_norm(input, normalized_shape, weight, bias, eps)
#    2909 if has_torch_function_variadic(input, weight, bias):
#    2910     return handle_torch_function(
#    2911         layer_norm,
#    2912         (input, weight, bias),
#    (...)   2917         eps=eps,
#    2918     )
# -> 2919 return torch.layer_norm(
#    2920     input, normalized_shape, weight, bias, eps, torch.backends.cudnn.enabled
#    2921 )
#
# KeyboardInterrupt:

# %% [markdown]
# # Otra forma

# %%
pip install evaluate datasets
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Requirement already satisfied: evaluate in /home/frank/miniconda3/envs/blackwell/lib/python3.12/site-packages (0.4.3)
# Requirement already satisfied: datasets in /home/frank/miniconda3/envs/blackwell/lib/python3.12/site-packages (3.6.0)
# Requirement already satisfied: numpy>=1.17 in /home/frank/miniconda3/envs/blackwell/lib/python3.12/site-packages (from evaluate) (2.3.0)
# Requirement already satisfied: dill in /home/frank/miniconda3/envs/blackwell/lib/python3.12/site-packages (from evaluate) (0.3.8)
# Requirement already satisfied: pandas in /home/frank/miniconda3/envs/blackwell/lib/python3.12/site-packages (from evaluate) (2.3.0)
# Requirement already satisfied: requests>=2.19.0 in /home/frank/miniconda3/envs/blackwell/lib/python3.12/site-packages (from evaluate) (2.32.4)
# Requirement already satisfied: tqdm>=4.62.1 in /home/frank/miniconda3/envs/blackwell/lib/python3.12/site-packages (from evaluate) (4.67.1)
# Requirement already satisfied: xxhash in /home/frank/miniconda3/envs/blackwell/lib/python3.12/site-packages (from evaluate) (3.5.0)
# Requirement already satisfied: multiprocess in /home/frank/miniconda3/envs/blackwell/lib/python3.12/site-packages (from evaluate) (0.70.16)
# Requirement already satisfied: fsspec>=2021.05.0 in /home/frank/miniconda3/envs/blackwell/lib/python3.12/site-packages (from fsspec[http]>=2021.05.0->evaluate) (2025.3.0)
# Requirement already satisfied: huggingface-hub>=0.7.0 in /home/frank/miniconda3/envs/blackwell/lib/python3.12/site-packages (from evaluate) (0.33.0)
# Requirement already satisfied: packaging in /home/frank/miniconda3/envs/blackwell/lib/python3.12/site-packages (from evaluate) (25.0)
# Requirement already satisfied: filelock in /home/frank/miniconda3/envs/blackwell/lib/python3.12/site-packages (from datasets) (3.18.0)
# Requirement already satisfied: pyarrow>=15.0.0 in /home/frank/miniconda3/envs/blackwell/lib/python3.12/site-packages (from datasets) (20.0.0)
# Requirement already satisfied: pyyaml>=5.1 in /home/frank/miniconda3/envs/blackwell/lib/python3.12/site-packages (from datasets) (6.0.2)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /home/frank/miniconda3/envs/blackwell/lib/python3.12/site-packages (from fsspec[http]>=2021.05.0->evaluate) (3.12.12)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /home/frank/miniconda3/envs/blackwell/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/frank/miniconda3/envs/blackwell/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /home/frank/miniconda3/envs/blackwell/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/frank/miniconda3/envs/blackwell/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/frank/miniconda3/envs/blackwell/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (6.4.4)
# Requirement already satisfied: propcache>=0.2.0 in /home/frank/miniconda3/envs/blackwell/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /home/frank/miniconda3/envs/blackwell/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (1.20.1)
# Requirement already satisfied: idna>=2.0 in /home/frank/miniconda3/envs/blackwell/lib/python3.12/site-packages (from yarl<2.0,>=1.17.0->aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (3.10)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/frank/miniconda3/envs/blackwell/lib/python3.12/site-packages (from huggingface-hub>=0.7.0->evaluate) (4.14.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.2 in /home/frank/miniconda3/envs/blackwell/lib/python3.12/site-packages (from huggingface-hub>=0.7.0->evaluate) (1.1.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/frank/miniconda3/envs/blackwell/lib/python3.12/site-packages (from requests>=2.19.0->evaluate) (3.4.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/frank/miniconda3/envs/blackwell/lib/python3.12/site-packages (from requests>=2.19.0->evaluate) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/frank/miniconda3/envs/blackwell/lib/python3.12/site-packages (from requests>=2.19.0->evaluate) (2025.4.26)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/frank/miniconda3/envs/blackwell/lib/python3.12/site-packages (from pandas->evaluate) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/frank/miniconda3/envs/blackwell/lib/python3.12/site-packages (from pandas->evaluate) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/frank/miniconda3/envs/blackwell/lib/python3.12/site-packages (from pandas->evaluate) (2025.2)
# Requirement already satisfied: six>=1.5 in /home/frank/miniconda3/envs/blackwell/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas->evaluate) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import torch
from transformers import AutoTokenizer, AutoModelForCausalLM
from datasets import load_dataset
from nltk.translate.bleu_score import sentence_bleu, SmoothingFunction
from evaluate import load as load_metric
import numpy as np
from tqdm import tqdm

# %%
# Configuración
MODEL_PATH = "./modelo"
DEVICE = "cuda" if torch.cuda.is_available() else "cpu"

tokenizer = AutoTokenizer.from_pretrained("gpt2")
tokenizer.pad_token = tokenizer.eos_token

model = AutoModelForCausalLM.from_pretrained(
    MODEL_PATH,
    local_files_only=True,
    torch_dtype=torch.float16 if DEVICE == "cuda" else torch.float32
).to(DEVICE)
model.eval()
# Out:
# GPT2LMHeadModel(
#   (transformer): GPT2Model(
#     (wte): Embedding(50257, 768)
#     (wpe): Embedding(1024, 768)
#     (drop): Dropout(p=0.1, inplace=False)
#     (h): ModuleList(
#       (0-11): 12 x GPT2Block(
#         (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (attn): GPT2Attention(
#           (c_attn): Conv1D(nf=2304, nx=768)
#           (c_proj): Conv1D(nf=768, nx=768)
#           (attn_dropout): Dropout(p=0.1, inplace=False)
#           (resid_dropout): Dropout(p=0.1, inplace=False)
#         )
#         (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (mlp): GPT2MLP(
#           (c_fc): Conv1D(nf=3072, nx=768)
#           (c_proj): Conv1D(nf=768, nx=3072)
#           (act): NewGELUActivation()
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#     )
#     (ln_f): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#   )
#   (lm_head): Linear(in_features=768, out_features=50257, bias=False)
# )

# %%
# Cargar dataset completo
data_files = {
    'train': 'dataset_train_filtrado.jsonl',
    'validation': 'dataset_valid_filtrado.jsonl',
    'test': 'dataset_test_filtrado.jsonl'
}
raw_datasets = load_dataset('json', data_files=data_files)
test_dataset = raw_datasets["test"]

# Tomar solo la tercera parte
subset_size = len(test_dataset) // 10
test_subset = test_dataset.select(range(subset_size))

# %%
def comentar_codigo(snippet):
    prompt = f"Comenta este código Python:\n```python\n{snippet}\n```\nCódigo comentado:\n```python\n"
    inputs = tokenizer(prompt, return_tensors="pt", truncation=True, max_length=512).to(DEVICE)

    with torch.no_grad():
        outputs = model.generate(
            **inputs,
            max_new_tokens=512,
            temperature=0.7,
            do_sample=False,
            pad_token_id=tokenizer.eos_token_id
        )
    full_output = tokenizer.decode(outputs[0], skip_special_tokens=True)
    comentado = full_output.split("Código comentado:")[-1].strip()
    return comentado.replace("```", "").strip()

# %%
rouge = load_metric("rouge")
meteor = load_metric("meteor")
# Out:
# [nltk_data] Downloading package wordnet to /home/frank/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /home/frank/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /home/frank/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!

# %%
refs, preds = [], []

for item in tqdm(test_subset):
    codigo_limpio = item["code_clean"]
    codigo_comentado_ref = item["code"]

    codigo_comentado_pred = comentar_codigo(codigo_limpio)

    refs.append(codigo_comentado_ref)
    preds.append(codigo_comentado_pred)
# Out:
#   0%|                                                  | 0/1991 [00:00<?, ?it/s]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
#   0%|                                        | 1/1991 [00:02<1:22:47,  2.50s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
#   0%|                                        | 2/1991 [00:04<1:13:47,  2.23s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
#   0%|                                          | 3/1991 [00:05<51:30,  1.55s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
#   0%|                                          | 4/1991 [00:07<58:17,  1.76s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
#   0%|                                        | 5/1991 [00:09<1:01:40,  1.86s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
#   0%|                                        | 6/1991 [00:11<1:03:38,  1.92s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
#   0%|▏                                       | 7/1991 [00:13<1:05:02,  1.97s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
#   0%|▏                                       | 8/1991 [00:15<1:05:50,  1.99s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
#   0%|▏                                       | 9/1991 [00:17<1:06:23,  2.01s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
#   1%|▏                                      | 10/1991 [00:19<1:06:39,  2.02s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
#   1%|▏                                      | 11/1991 [00:21<1:06:56,  2.03s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
#   1%|▏                                      | 12/1991 [00:23<1:07:05,  2.03s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
#   1%|▎                                      | 13/1991 [00:25<1:07:06,  2.04s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
#   1%|▎                                      | 14/1991 [00:27<1:07:01,  2.03s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
#   1%|▎                                        | 15/1991 [00:28<56:29,  1.72s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
#   1%|▎                                        | 16/1991 [00:30<59:41,  1.81s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
#   1%|▎                                      | 17/1991 [00:32<1:01:46,  1.88s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
#   1%|▎                                      | 18/1991 [00:34<1:03:18,  1.93s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
#   1%|▍                                        | 19/1991 [00:35<47:14,  1.44s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
#   1%|▍                                        | 20/1991 [00:37<53:06,  1.62s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
#   1%|▍                                        | 21/1991 [00:39<57:06,  1.74s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
#   1%|▍                                        | 22/1991 [00:41<59:58,  1.83s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
#   1%|▍                                      | 23/1991 [00:43<1:01:55,  1.89s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
#   1%|▍                                      | 24/1991 [00:45<1:03:20,  1.93s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
#   1%|▍                                      | 25/1991 [00:47<1:04:24,  1.97s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
#   1%|▌                                      | 26/1991 [00:49<1:05:06,  1.99s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
#   1%|▌                                      | 27/1991 [00:51<1:05:39,  2.01s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
#   1%|▌                                      | 28/1991 [00:53<1:06:05,  2.02s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
#   1%|▌                                      | 29/1991 [00:55<1:06:36,  2.04s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
#   2%|▌                                      | 30/1991 [00:57<1:07:01,  2.05s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
#   2%|▌                                      | 31/1991 [00:59<1:07:06,  2.05s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
#   2%|▋                                      | 32/1991 [01:01<1:06:59,  2.05s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
#   2%|▋                                      | 33/1991 [01:03<1:06:56,  2.05s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
#   2%|▋                                        | 34/1991 [01:04<57:27,  1.76s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
#   2%|▋                                      | 35/1991 [01:06<1:00:10,  1.85s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
#   2%|▋                                      | 36/1991 [01:09<1:02:14,  1.91s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
#   2%|
68s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
#  97%|█████████████████████████████████████▉ | 1938/1991 [59:56<01:10,  1.33s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
#  97%|█████████████████████████████████████▉ | 1939/1991 [59:58<01:20,  1.55s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
#  97%|████████████████████████████████████ | 1940/1991 [1:00:00<01:27,  1.71s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
#  97%|████████████████████████████████████ | 1941/1991 [1:00:02<01:30,  1.81s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
#  98%|████████████████████████████████████ | 1942/1991 [1:00:03<01:11,  1.45s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
#  98%|████████████████████████████████████ | 1943/1991 [1:00:03<00:53,  1.11s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
#  98%|████████████████████████████████████▏| 1944/1991 [1:00:05<01:05,  1.40s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
#  98%|████████████████████████████████████▏| 1945/1991 [1:00:06<00:54,  1.18s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
#  98%|████████████████████████████████████▏| 1946/1991 [1:00:08<01:04,  1.44s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
#  98%|████████████████████████████████████▏| 1947/1991 [1:00:10<01:11,  1.63s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
#  98%|████████████████████████████████████▏| 1948/1991 [1:00:12<01:15,  1.76s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
#  98%|████████████████████████████████████▏| 1949/1991 [1:00:14<01:17,  1.85s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
#  98%|████████████████████████████████████▏| 1950/1991 [1:00:16<01:18,  1.92s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
#  98%|████████████████████████████████████▎| 1951/1991 [1:00:18<01:18,  1.96s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
#  98%|████████████████████████████████████▎| 1952/1991 [1:00:20<01:17,  1.99s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
#  98%|████████████████████████████████████▎| 1953/1991 [1:00:22<01:16,  2.02s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
#  98%|████████████████████████████████████▎| 1954/1991 [1:00:24<01:15,  2.04s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
#  98%|████████████████████████████████████▎| 1955/1991 [1:00:24<00:53,  1.48s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
#  98%|████████████████████████████████████▎| 1956/1991 [1:00:25<00:39,  1.14s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
#  98%|████████████████████████████████████▎| 1957/1991 [1:00:26<00:34,  1.00s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
#  98%|████████████████████████████████████▍| 1958/1991 [1:00:28<00:43,  1.33s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
#  98%|████████████████████████████████████▍| 1959/1991 [1:00:28<00:34,  1.07s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
#  98%|████████████████████████████████████▍| 1960/1991 [1:00:30<00:42,  1.37s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
#  98%|████████████████████████████████████▍| 1961/1991 [1:00:32<00:47,  1.58s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
#  99%|████████████████████████████████████▍| 1962/1991 [1:00:34<00:50,  1.73s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
#  99%|████████████████████████████████████▍| 1963/1991 [1:00:36<00:51,  1.84s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
#  99%|████████████████████████████████████▍| 1964/1991 [1:00:38<00:51,  1.90s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
#  99%|████████████████████████████████████▌| 1965/1991 [1:00:41<00:50,  1.95s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
#  99%|████████████████████████████████████▌| 1966/1991 [1:00:43<00:49,  1.98s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
#  99%|████████████████████████████████████▌| 1967/1991 [1:00:45<00:48,  2.01s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
#  99%|████████████████████████████████████▌| 1968/1991 [1:00:45<00:34,  1.51s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
#  99%|████████████████████████████████████▌| 1969/1991 [1:00:45<00:26,  1.19s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
#  99%|████████████████████████████████████▌| 1970/1991 [1:00:48<00:30,  1.46s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
#  99%|████████████████████████████████████▋| 1971/1991 [1:00:50<00:32,  1.64s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
#  99%|████████████████████████████████████▋| 1972/1991 [1:00:52<00:33,  1.77s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
#  99%|████████████████████████████████████▋| 1973/1991 [1:00:54<00:33,  1.86s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
#  99%|████████████████████████████████████▋| 1974/1991 [1:00:56<00:32,  1.93s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
#  99%|████████████████████████████████████▋| 1975/1991 [1:00:58<00:31,  1.97s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
#  99%|████████████████████████████████████▋| 1976/1991 [1:00:58<00:22,  1.49s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
#  99%|████████████████████████████████████▋| 1977/1991 [1:01:00<00:23,  1.66s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
#  99%|████████████████████████████████████▊| 1978/1991 [1:01:02<00:23,  1.79s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
#  99%|████████████████████████████████████▊| 1979/1991 [1:01:03<00:16,  1.40s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
#  99%|████████████████████████████████████▊| 1980/1991 [1:01:05<00:17,  1.59s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
#  99%|████████████████████████████████████▊| 1981/1991 [1:01:07<00:17,  1.73s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# 100%|████████████████████████████████████▊| 1982/1991 [1:01:09<00:16,  1.83s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# 100%|████████████████████████████████████▊| 1983/1991 [1:01:11<00:15,  1.90s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# 100%|████████████████████████████████████▊| 1984/1991 [1:01:13<00:13,  1.94s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# 100%|████████████████████████████████████▉| 1985/1991 [1:01:15<00:11,  1.98s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# 100%|████████████████████████████████████▉| 1986/1991 [1:01:17<00:10,  2.00s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# 100%|████████████████████████████████████▉| 1987/1991 [1:01:19<00:08,  2.02s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# 100%|████████████████████████████████████▉| 1988/1991 [1:01:21<00:06,  2.03s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# 100%|████████████████████████████████████▉| 1989/1991 [1:01:23<00:04,  2.04s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# 100%|████████████████████████████████████▉| 1990/1991 [1:01:26<00:02,  2.05s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# 100%|█████████████████████████████████████| 1991/1991 [1:01:28<00:00,  1.85s/it]

# %%
# BLEU
smoothie = SmoothingFunction().method4
bleu_scores = [
    sentence_bleu(
        [ref.split()],
        pred.split(),
        smoothing_function=smoothie
    ) for ref, pred in zip(refs, preds)
]
bleu_avg = np.mean(bleu_scores)

# ROUGE
rouge_result = rouge.compute(predictions=preds, references=refs, use_stemmer=True)

# METEOR
meteor_result = meteor.compute(predictions=preds, references=refs)

# Mostrar resultados
print(f"\nBLEU score promedio: {bleu_avg:.4f}")
print(f"METEOR: {meteor_result['meteor']:.4f}")
print(f"ROUGE-L: {rouge_result['rougeL']:.4f}")
# Out:
# BLEU score promedio: 0.1075
# METEOR: 0.2438
# ROUGE-L: 0.3532
